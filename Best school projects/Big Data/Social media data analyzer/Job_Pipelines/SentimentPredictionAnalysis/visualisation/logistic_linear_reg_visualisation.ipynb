# %%
# Sentiment Predictions using Visualisations

from IPython.display import Image, display

with open('linear_results.txt', 'r') as f1:
    text1 = f1.read()
with open('logistic_results.txt', 'r') as f2:
    text2 = f2.read()

print("------------------------------------------------------- Linear Regression Results -------------------------------------------------------")
print(text1 + "\n")
print("------------------------------------------------------- Logistic Regression Results -------------------------------------------------------")
print(text2)

print("\n----- Displaying JPEG Images -----")

# Replace 'image1.jpg' and 'image2.jpg' with your actual image file names/paths
display(Image(filename='linear_visualisation.jpg'))
display(Image(filename='logistic_visualisation.jpg'))
# Out:
# ------------------------------------------------------- Linear Regression Results -------------------------------------------------------
# ...
